# %% [markdown]
# # Welcome to your first assignment!
#
# Instructions are below. Please give this a try, and look in the solutions folder if you get stuck (or feel free to ask me!)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Just before we get to the assignment --</h2>
#             <span style="color:#f71;">I thought I'd take a second to point you at this page of useful resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # HOMEWORK EXERCISE ASSIGNMENT
#
# Upgrade the day 1 project to summarize a webpage to use an Open Source model running locally via Ollama rather than OpenAI
#
# You'll be able to use this technique for all subsequent projects if you'd prefer not to use paid APIs.
#
# **Benefits:**
# 1. No API charges - open-source
# 2. Data doesn't leave your box
#
# **Disadvantages:**
# 1. Significantly less power than Frontier Model
#
# ## Recap on installation of Ollama
#
# Simply visit [ollama.com](https://ollama.com) and install!
#
# Once complete, the ollama server should already be running locally.
# If you visit:
# [http://localhost:11434/](http://localhost:11434/)
#
# You should see the message `Ollama is running`.
#
# If not, bring up a new Terminal (Mac) or Powershell (Windows) and enter `ollama serve`
# And in another Terminal (Mac) or Powershell (Windows), enter `ollama pull llama3.2`
# Then try [http://localhost:11434/](http://localhost:11434/) again.
#
# If Ollama is slow on your machine, try using `llama3.2:1b` as an alternative. Run `ollama pull llama3.2:1b` from a Terminal or Powershell, and change the code below from `MODEL = "llama3.2"` to `MODEL = "llama3.2:1b"`

# %%
# imports

import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# Constants

OLLAMA_API = "http://localhost:11434/api/chat" # URL on local on this port which is the port that ollama runs on
HEADERS = {"Content-Type": "application/json"} #
MODEL = "llama3.2"

# %%
# Create a messages list using the same format that we used for OpenAI

messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
# Let's just make sure the model is loaded

# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# If this doesn't work for any reason, try the 2 versions in the following cells
# And double check the instructions in the 'Recap on installation of Ollama' at the top of this lab
# And if none of that works - contact me!

response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries, including:
#
# 1. **Content Creation**: Generative AI can be used to create high-quality content such as articles, social media posts, product descriptions, and even entire websites. This can help reduce content creation costs and increase efficiency.
# 2. **Marketing Automation**: Generative AI can be used to generate personalized marketing messages, emails, and ads that are tailored to individual customers' needs and preferences.
# 3. **Product Design**: Generative AI can be used to design new products, such as furniture, clothing, or electronics, by generating 3D models and prototypes.
# 4. **Image and Video Generation**: Generative AI can be used to generate high-quality images and videos for marketing campaigns, advertising, and social media platforms.
# 5. **Chatbots and Virtual Assistants**: Generative AI can be used to create more advanced chatbots and virtual assistants that can understand natural language and respond accordingly.
# 6. **Predictive Maintenance**: Generative AI can be used to analyze sensor data from machines and predict when maintenance is needed, reducing downtime and increasing efficiency.
# 7. **Personalized Recommendations**: Generative AI can be used to generate personalized product recommendations based on customer behavior, preferences, and demographics.
# 8. **Data Annotation**: Generative AI can be used to automate the process of annotating large datasets with relevant labels and tags, which is a time-consuming task for human annotators.
# 9. **Network Generation**: Generative AI can be used to generate new network connections, routes, or paths that are more efficient than existing ones, reducing congestion and increasing productivity.
# 10. **Finance and Accounting**: Generative AI can be used to automate financial analysis, risk assessment, and accounting tasks, such as reconciling accounts and generating financial reports.
#
# Some specific examples of business applications of Generative AI include:
#
# * **Google's Duplex**: a chatbot that uses Generative AI to generate realistic conversations with humans.
# * **Amazon's SageMaker**: a platform that allows businesses to build and deploy machine learning models, including those using Generative AI.
# * **Microsoft's Azure Machine Learning**: a cloud-based platform that provides tools for building, training, and deploying machine learning models, including those using Generative AI.
# * **Salesforce's Einstein Analytics**: a platform that uses Generative AI to analyze customer data and provide personalized insights.
#
# These are just a few examples of the many business applications of Generative AI. As the technology continues to evolve, we can expect to see even more innovative uses across various industries.

# %% [markdown]
# # Introducing the ollama package
#
# And now we'll do the same thing, but using the elegant ollama python package instead of a direct HTTP call.
#
# Under the hood, it's making the same call as above to the ollama server running at localhost:11434

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries, including:
#
# 1. **Content Creation**: AI-powered tools can generate high-quality content such as blog posts, social media posts, product descriptions, and more, saving time and increasing efficiency.
# 2. **Product Design and Development**: Generative AI can be used to design new products, packaging, and branding materials, reducing the need for manual design and iteration.
# 3. **Marketing Automation**: AI-powered tools can generate personalized marketing campaigns, targeting specific audiences and optimizing messaging for better engagement.
# 4. **Customer Service**: Chatbots and virtual assistants powered by generative AI can provide 24/7 customer support, answering frequently asked questions and routing complex issues to human representatives.
# 5. **Data Analysis and Visualization**: Generative AI can help analyze large datasets, identify patterns, and generate insights, enabling data-driven decision-making.
# 6. **Financial Modeling and Predictive Analytics**: AI-powered tools can analyze historical data, forecast future trends, and provide predictive models for financial planning and risk management.
# 7. **User Experience (UX) Design**: Generative AI can help design intuitive user interfaces, optimize navigation, and create personalized experiences based on user behavior.
# 8. **Creative Writing and Storytelling**: AI-powered tools can generate scripts, articles, and stories, assisting writers with research, organization, and idea development.
# 9. **Cybersecurity Threat Analysis**: Generative AI can analyze threat intelligence data, identify potential security threats, and provide predictive insights to inform incident response strategies.
# 10. **Supply Chain Optimization**: AI-powered tools can optimize logistics, predict demand, and streamline supply chain operations, reducing costs and improving efficiency.
#
# Some specific examples of business applications of generative AI include:
#
# * **Salesforce's Einstein**: A cloud-based platform that uses generative AI to analyze customer behavior, predict sales, and optimize marketing campaigns.
# * **H&M's Generative Design**: An AI-powered design tool that allows designers to create sustainable fashion products using 3D printing technology.
# * **The New York Times' AI-generated content**: The newspaper has used AI to generate some of its news articles, allowing for faster turnaround times and increased efficiency.
#
# These are just a few examples of the many ways in which generative AI is being applied in business. As the technology continues to evolve, we can expect to see even more innovative applications across various industries.

# %% [markdown]
# ## Alternative approach - using OpenAI python library to connect to Ollama

# %%
# There's actually an alternative approach that some people might prefer
# You can use the OpenAI client python library to call Ollama:

from openai import OpenAI
ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

response = ollama_via_openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# Generative Artificial Intelligence (AI) has numerous business applications across various industries, transforming the way businesses operate and creating new opportunities for growth. Here are some examples:
#
# 1. **Content Generation**: Generative AI can create high-quality content such as:
# 	* Blog posts and articles
# 	* Social media posts and ads
# 	* Product descriptions and testimonials
# 	* Music and videos
# 	* Books and e-books
#
# This saves time, reduces costs, and increases content consistency.
#
# 2. **Image and Video Generation**: Generative AI can create realistic images and videos for:
# 	* Marketing and advertising campaigns (e.g., product demonstrations, explainer videos)
# 	* Social media and e-commerce platforms
# 	* Branding and visual identity (e.g., logos, corporate videos)
#
# This enables businesses to create engaging content without the need for extensive manual efforts.
#
# 3. **Customization and Personalization**: Generative AI can generate personalized experiences, such as:
# 	* Custom product designs
# 	* Branded merchandise
# 	* Tires (using AI to produce customized products with unique details)
# 	* Financial planning and investment tools
#
# This helps businesses tailor their offerings to individual customers or niche markets.
#
# 4. **Chatbots and Virtual Assistants**: Generative AI enables the creation of conversational interfaces for:
# 	* Customer support
# 	* Technical assistance
# 	* Education and coaching
# 	* Marketing and sales automation
#
# Businesses can leverage AI-powered chatbots to provide 24/7 support, free up human resources, and improve customer engagement.
#
# 5. **Data Analysis and Predictive Insights**: Generative AI can analyze large datasets and generate predictive models for:
# 	* Customer segmentation and prioritization
# 	* Market trend analysis and forecasting
# 	* Personalized product recommendations
# 	* Fraud detection and risk assessment
#
# This provides businesses with actionable insights to make data-driven decisions.
#
# 6. **Design and Prototyping**: Generative AI tools can assist in the design process by generating:
# 	* Concept art and visualizations
# 	* Technical specifications for products or infrastructure (e.g., architecture, engineering)
# 	* Furniture and product designs
#
# Businesses can streamline their design workflows and explore new ideas more efficiently.
#
# 7. **Supply Chain Optimization**: Generative AI can analyze complex supply chain networks to identify:
# 	* Bottleneck nodes
# 	* Route optimization
# 	* Logistics scheduling
#
# By leveraging AI in supply chain management, businesses can improve efficiency, reduce costs, and enhance product delivery times.
#
# 8. **Cybersecurity Analysis**: Generative AI can analyze large data sets to identify potential threats and predict attacks on:
# 	* Network systems
# 	* Cloud infrastructure
# 	* Financial institutions
#
# The insights generated by generative AI enable security teams to proactively detect and respond to threats, reducing the risk of cyber attacks.
#
# These examples illustrate how generative AI is being applied across various industries and use cases. As this technology continues to evolve, we can expect even more innovative applications across business ecosystems.

# %% [markdown]
# ## Are you confused about why that works?
#
# It seems strange, right? We just used OpenAI code to call Ollama?? What's going on?!
#
# Here's the scoop:
#
# The python class `OpenAI` is simply code written by OpenAI engineers that makes calls over the internet to an endpoint.
#
# When you call `openai.chat.completions.create()`, this python code just makes a web request to the following url: "https://api.openai.com/v1/chat/completions"
#
# Code like this is known as a "client library" - it's just wrapper code that runs on your machine to make web requests. The actual power of GPT is running on OpenAI's cloud behind this API, not on your computer!
#
# OpenAI was so popular, that lots of other AI providers provided identical web endpoints, so you could use the same approach.
#
# So Ollama has an endpoint running on your local box at http://localhost:11434/v1/chat/completions
# And in week 2 we'll discover that lots of other providers do this too, including Gemini and DeepSeek.
#
# And then the team at OpenAI had a great idea: they can extend their client library so you can specify a different 'base url', and use their library to call any compatible API.
#
# That's it!
#
# So when you say: `ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')`
# Then this will make the same endpoint calls, but to Ollama instead of OpenAI.

# %% [markdown]
# ## Also trying the amazing reasoning model DeepSeek
#
# Here we use the version of DeepSeek-reasoner that's been distilled to 1.5B.
# This is actually a 1.5B variant of Qwen that has been fine-tuned using synethic data generated by Deepseek R1.
#
# Other sizes of DeepSeek are [here](https://ollama.com/library/deepseek-r1) all the way up to the full 671B parameter version, which would use up 404GB of your drive and is far too large for most!

# %%
# !ollama pull deepseek-r1:1.5b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest
# pulling aabd4debf0c8... 100% ▕████████████████▏ 1.1 GB
# pulling 369ca498f347... 100% ▕████████████████▏  387 B
# pulling 6e4c38e1172f... 100% ▕████████████████▏ 1.1 KB
# pulling f4d24e9138dd... 100% ▕████████████████▏  148 B
# pulling a85fe2a2e58e... 100% ▕████████████████▏  487 B
# verifying sha256 digest
# writing manifest
# success

# %%
# This may take a few minutes to run! You should then see a fascinating "thinking" trace inside <think> tags, followed by some decent definitions

response = ollama_via_openai.chat.completions.create(
    model="deepseek-r1:1.5b",
    messages=[{"role": "user", "content": "Please give definitions of some core concepts behind LLMs: a neural network, attention and the transformer"}]
)

print(response.choices[0].message.content)
# Out:
# <think>
# Okay, so I need to figure out what defines some core concepts behind large language models (LLMs), especially focusing on neural networks, attention, and the transformer. Hmm, where do I start?
#
# First, let me think about what an LLM is. From what I remember, it's a type of AI that can understand and generate human-level text, like writing stories or translating languages. These models are really good at learning patterns from vast amounts of data and using that knowledge to create new sentences.
#
# Now, looking at neural networks as the core concept. I know that neural networks are a class of machine learning models inspired by the structure and function of the human brain's biological neural network. They consist of layers of interconnected nodes or neurons. In LLMs, they're probably used in something called "pre训练" or "fine-tuning". So each model has its own set of weights that it learns from its data. When you use an LLM to generate text, you give it some starting data, and the network adjusts those weights to understand what sequences of words are likely to come up next.
#
# Next is attention. I've heard about this term a lot in recent AI news. It's related to how models focus on different parts of their input when processing information. Maybe in LLMs, once they have some initial data or context from the prompt, the model "focuses" its output by paying more attention to specific tokens within that input.
#
# Then there's the transformer itself. I think all these things are part of a common structure called transformers, which introduced a massive improvement over traditional recurrent neural networks (RNNs) in ML when it came to NLP tasks. Transformers use self-attention mechanisms where each token in the model looks forward and backward in time (from its own perspective during training or inference), using multi-head attention. Each head can focus on different parts of the input, helping the model capture complex patterns.
#
# I'm a little confused about how all these fit together. The LLM itself, right? Once trained, it's called a large language model and has both vision and understanding capabilities as an AI. So when you give it a text prompt like a story or a poem, it processes that through the transformer, attends to important parts of the input via attention, and then uses all those learned patterns to generate new text.
#
# Wait, is "attention" always part of the transformers? Maybe other approaches do too, but I think transformers are the prominent one. Also, maybe in some models like GPTs (which is an example of LLM), they might only use a subset of the model's parameters, like only the 'heads' through attention. But perhaps all major models rely heavily on the transformers for their ability to process information.
#
# I guess understanding this makes me realize how powerful these concepts are and how each part contributes to the model's capabilities. But I should verify if there are any other core concepts too related to LLMs—like generalization, efficiency, or maybe some mention of hardware advancements beyond T4? Although I'm not very clear on those specifics.
#
# In summary, a neural network in an LLM probably consists of layers that process inputs through weights learned from data. Attention within the model helps focus on specific parts of the input, and transformers enable efficient processing using self-attention mechanisms across all tokens.
# </think>
#
# **Core Concepts Behind Large Language Models (LLMs):**
#
# 1. **Neural Network Architecture:**
#    - A neural network in an LLM is composed of interconnected layers designed to process complex patterns from input data. These models are initialized with weights learned from pretraining on vast datasets, enabling them to generalize and generate contextualized outputs by adjusting these weights during inference.
#
# 2. **Attention Mechanism:**
#    - The attention component allows the model to focus on specific parts of its input when processing information. In LLMs, this mechanism helps prioritize tokens by considering their context from both directions, which is crucial for capturing nuanced patterns and dependencies in text.
#
# 3. **Transformer architecture:**
#    - Transformers, a cornerstone introduced by architectures like GPT, utilize self-attention and multi-head attention to analyze input sequences comprehensively. Each token examines all others simultaneously across time, enabling efficient pattern recognition and interaction between different parts of the model.
#
# In summary, an LLM's core elements are supported by neural networks for learning patterns, attention mechanisms for focused processing, and transformers for advanced sequence analysis, collectively enabling their ability to generate high-quality text.

# %% [markdown]
# # NOW the exercise for you
#
# Take the code from day1 and incorporate it here, to build a website summarizer that uses Llama 3.2 running locally instead of OpenAI; use either of the above approaches.

# %%
import ollama
from IPython.display import Markdown, display

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

web = "https://elpais.com"
user_prompt = user_prompt_for(Website(web))

# Step 2: Make the messages list

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]


MODEL = "llama3.2"
response = ollama.chat(model=MODEL, messages=messages)
summary = response['message']['content']

display(Markdown(summary))
# Out:
# ¡Hola! Parece que tienes una gran cantidad de opciones para encontrar información y entretenimiento en el sitio web de El País. Aquí te presento algunas sugerencias para comenzar:
#
# 1. **Accede a las secciones más populares**: Las secciones más visitadas pueden ser "Últimas noticias", "Hemeroteca" y "Especiales". Estas áreas suelen tener información actualizada sobre los últimos acontecimientos, artículos recientes y análisis en profundidad.
# 2. **Explora las secciones temáticas**: Si estás interesado en un tema específico, como la economía, el deporte o la cultura, puedes buscar en las secciones correspondientes. Por ejemplo, "Economía" o "Deportes".
# 3. **Utiliza la barra de búsqueda**: La barra de búsqueda en la parte superior del sitio web te permite buscar artículos y contenido específicos.
# 4. **Visita las secciones de entretenimiento**: Si estás interesado en la cultura popular, el cine o la música, puedes encontrar información en las secciones "S moda", "Gastro" y "El Comidista".
# 5. **Descubre los podcasts y videos**: El País ofrece una variedad de podcasts y videos en su sitio web. Puedes encontrar artículos en audio o video en las secciones "Podcasts" y "Vídeos".
#
# Recuerda que puedes personalizar tu experiencia en el sitio web de El País agregando tus preferencias de noticias y contenido a la página de inicio. ¡Disfruta explorando!

# %%
import requests
from bs4 import BeautifulSoup
import ollama
from IPython.display import Markdown, display

class Website:
    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
            }
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup(["script", "style", "img", "input"]):
        #for irrelevant in soup(["script", "style", "img", "input", "nav", "footer", "aside", "header"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

class SummarizeWebsite(Website):
    def __init__(
            self,
            model: str="llama3.2",
            url: str=None,
    ):
        super().__init__(url)

        self.model = model
        
    def summarize(self):    

        system_prompt = "You are an assistant that analyzes the contents of a website \
                        and provides a short summary, ignoring text that might be navigation related. \
                        Respond in markdown."
        
        user_prompt = f"You are looking at a website titled {self.title}"
        user_prompt += "\nThe contents of this website is as follows; \
                    please provide a short summary of this website in markdown. \
                    If it includes news or announcements, then summarize these too.\n\n"
        user_prompt += self.text

        print(self.title)
        
        messages = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
            ]
        
        response = ollama.chat(model=self.model, messages=messages)
        summary = response['message']['content']
        display(Markdown(summary))

        return summary
        
site = SummarizeWebsite(model="llama3.2", url="https://edwarddonner.com")  #edwarddonner.com
site.summarize()
# Out:
# Home - Edward Donner
# # Website Summary
#
# ## About the Author and Company
#
# The website is owned by Edward Donner, a co-founder and CTO of Nebula.io. He shares his interests in writing code, experimenting with Large Language Models (LLMs), DJing, and amateur electronic music production.
#
# ## News and Announcements
#
# * **December 21, 2024**: LLM Workshop – Hands-on with Agents – resources
# * **November 13, 2024**: Welcome, SuperDataScientists!
# * **October 16, 2024**: From Software Engineer to AI Data Scientist – resources
# * **Mastering AI and LLM Engineering – Resources** (no specific date mentioned)
# * **January 23, 2025**: LLM Workshop – Hands-on with Agents – resources
#
# ## Additional Information
#
# Edward Donner is the founder and CEO of AI startup untapt, which was acquired in 2021. Nebula.io applies AI to help people discover their potential and pursue their reason for being.
# '# Website Summary\n\n## About the Author and Company\n\nThe website is owned by Edward Donner, a co-founder and CTO of Nebula.io. He shares his interests in writing code, experimenting with Large Language Models (LLMs), DJing, and amateur electronic music production.\n\n## News and Announcements\n\n* **December 21, 2024**: LLM Workshop – Hands-on with Agents – resources\n* **November 13, 2024**: Welcome, SuperDataScientists!\n* **October 16, 2024**: From Software Engineer to AI Data Scientist – resources\n* **Mastering AI and LLM Engineering – Resources** (no specific date mentioned)\n* **January 23, 2025**: LLM Workshop – Hands-on with Agents – resources\n\n## Additional Information\n\nEdward Donner is the founder and CEO of AI startup untapt, which was acquired in 2021. Nebula.io applies AI to help people discover their potential and pursue their reason for being.'
